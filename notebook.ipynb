# %% [markdown]
# # Welcome to Your Python Notebook
#
# This is a Jupyter notebook for data analysis and exploration.

# %%
# Import libraries
import sys
print(f"Python version: {sys.version}")

# %%
# Your code here
